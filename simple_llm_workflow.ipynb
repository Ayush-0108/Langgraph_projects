# %%
from langgraph.graph import StateGraph,START,END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="openai/gpt-oss-20b")

# %%
class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state:LLMState)->LLMState:
    question = state["question"]
    prompt = f"Answer the following question {question}"
    answer = model.invoke(prompt).content
    state["answer"] = answer
    return state

# %%
graph = StateGraph(LLMState)

graph.add_node("llm_qa",llm_qa)

graph.add_edge(START,"llm_qa")
graph.add_edge("llm_qa",END)

workflow = graph.compile()

# %%
initial_state = {"question":"what is the science behind moon phases"}
output_state = workflow.invoke(initial_state)

# %%
print(output_state["answer"])
# Out:
# **Moon phases – the science in a nutshell**
#
# | Concept | What it means | Why it matters |
# |--------|----------------|----------------|
# | **Geometry of the Sun‑Earth‑Moon system** | The Moon orbits Earth once every ≈27.3 days (sidereal month).  Relative to the Sun the cycle is ≈29.53 days (synodic month). | The changing angle between the Sun, Moon, and Earth determines how much of the Moon’s sun‑lit side is visible from Earth. |
# | **Tidal locking** | The Moon’s rotation period equals its orbital period, so the same hemisphere always faces Earth. | Because we see only one face, the *changing* visible illuminated fraction is what we call the phases. |
# | **Phase angle** | The angle at the Moon between the Sun and Earth.  0° = new moon, 180° = full moon. | The phase angle directly gives the illuminated fraction (≈½ (1 + cos α)). |
# | **Illumination fraction** | The percentage of the Moon’s visible disk that is lit by the Sun. | It changes smoothly through the synodic month, producing the eight “classical” phases. |
# | **Terminators and shadows** | The line dividing day and night on the Moon moves from east to west as the Moon rotates. | The terminator’s position determines the shading and “crescent” shape we see. |
# | **Orbital inclination** | The Moon’s orbit is tilted ≈5° to the ecliptic. | This causes the Moon’s path to rise and set slightly north or south of the celestial equator, affecting the apparent latitude of the phases. |
#
# ### How the phases evolve
#
# 1. **New Moon** – The Moon is between the Sun and Earth.  The sun‑lit side faces away from us; the illuminated fraction is 0 %.
# 2. **Waxing Crescent** – As the Moon moves eastward, a thin sliver of light appears on the right (in the northern hemisphere).  Illumination increases from 0 % to 50 %.
# 3. **First Quarter** – The Moon has moved 90° from the Sun; half of its disk is lit (50 %).
# 4. **Waxing Gibbous** – More than half of the disk is lit (50 %–100 %).
# 5. **Full Moon** – The Earth lies between the Sun and Moon; the entire near side is illuminated (100 %).
# 6. **Waning Gibbous** – The illuminated fraction decreases from 100 % back toward 50 %.
# 7. **Last Quarter** – The Moon again shows a half‑lit disk, but the left side is illuminated.
# 8. **Waning Crescent** – Only a small sliver remains, decreasing to 0 % at the next new moon.
#
# The cycle repeats every **≈29.53 days** – the synodic month – because the Moon must travel ~360° relative to the Sun, not just to the stars.
#
# ### Key physical points
#
# - **No intrinsic light** – The Moon is dark; it reflects sunlight.
# - **Same face visible** – Because of tidal locking, we never see the Moon’s far side, so the phases are purely geometric.
# - **Illumination vs. distance** – The phases are almost independent of the Moon’s distance from Earth; the slight change in distance (perigee vs. apogee) only modestly affects apparent size, not the phase.
# - **Predictability** – Orbital mechanics (Kepler’s laws, Newton’s gravity) allow precise predictions of phase dates, times, and illumination fractions.
#
# ### Practical uses
#
# - **Calendars & timekeeping** – Many cultures built lunar calendars based
